# %% [markdown]
# <h1>Fluorescence Analysis</h1>

# %%
from tools import uvvis
from importlib import reload
reload(uvvis)

uv = uvvis.UI()
# Out:
# Box(children=(FileUpload(value=(), accept='.csv, .xlsx', description='Select File', layout=Layout(width='170px…
# Output()
# Output()
